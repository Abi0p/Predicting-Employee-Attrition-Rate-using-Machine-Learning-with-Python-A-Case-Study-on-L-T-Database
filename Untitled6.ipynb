# %% [markdown]
# <a href="https://colab.research.google.com/github/Abi0p/Predicting-Employee-Attrition-Rate-using-Machine-Learning-with-Python-A-Case-Study-on-L-T-Database/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel('L&T Data Source.xlsx')

# %%
data.head()
# Out:
#    EmployeeID   Age  Gender EducationLevel                JobRole  \
# 0         1.0  37.0  Female       Bachelor                Manager
# 1         2.0  48.0  Female       Bachelor  Laboratory Technician
# 2         3.0  22.0  Female         Master        Sales Executive
# 3         4.0  27.0    Male       Bachelor                Manager
# 4         5.0  48.0    Male       Bachelor                Manager
#
#    MonthlyIncome  YearsAtCompany WorkLifeBalance  JobSatisfaction OverTime  \
# 0    6524.325054            30.0             Bad              4.0       No
# 1    4665.239398             5.0          Better              4.0      Yes
# 2   17600.801537            37.0            Good              3.0      Yes
# 3   16778.033975            24.0            Best              1.0      Yes
# 4   15510.799372             1.0             NaN              3.0       No
#
#    DistanceFromHome  PerformanceRating Attrition
# 0              29.0                2.0        No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         90056 non-null  float64
#  1   Age                90136 non-null  float64
#  2   Gender             89952 non-null  object
#  3   EducationLevel     90054 non-null  object
#  4   JobRole            90102 non-null  object
#  5   MonthlyIncome      89859 non-null  float64
#  6   YearsAtCompany     89867 non-null  float64
#  7   WorkLifeBalance    89862 non-null  object
#  8   JobSatisfaction    90054 non-null  float64
#  9   OverTime           90099 non-null  object
#  10  DistanceFromHome   89916 non-null  float64
#  11  PerformanceRating  90050 non-null  float64
#  12  Attrition          89993 non-null  object
# dtypes: float64(7), object(6)
# memory usage: 9.9+ MB

# %%
#data preprocessing
data.isnull().sum()
# Out:
# EmployeeID            9944
# Age                   9864
# Gender               10048
# EducationLevel        9946
# JobRole               9898
# MonthlyIncome        10141
# YearsAtCompany       10133
# WorkLifeBalance      10138
# JobSatisfaction       9946
# OverTime              9901
# DistanceFromHome     10084
# PerformanceRating     9950
# Attrition            10007
# dtype: int64

# %%
data.shape
# Out:
# (100000, 13)

# %%
# Fill numeric columns with the median
numeric_columns = data.select_dtypes(include=['float','int']).columns
data[numeric_columns]=data[numeric_columns].fillna(data[numeric_columns].median())
#Fill categorical columns with most flequent values
categorical_columns = data.select_dtypes(include=['object']).columns
data[categorical_columns]= data[categorical_columns].fillna(data[categorical_columns].mode().iloc[0])

# %%
data.isnull().sum()
# Out:
# EmployeeID           0
# Age                  0
# Gender               0
# EducationLevel       0
# JobRole              0
# MonthlyIncome        0
# YearsAtCompany       0
# WorkLifeBalance      0
# JobSatisfaction      0
# OverTime             0
# DistanceFromHome     0
# PerformanceRating    0
# Attrition            0
# dtype: int64

# %%
#check duplicate recordss
data.duplicated().sum()
# Out:
# 0

# %%
# Replace 'Yes' with 1 and 'No' with 0 in the 'Attrition' column
data['Attrition'] = data['Attrition'].replace({'Yes': 1, 'No': 0})
print(data['Attrition'].value_counts())
# Out:
# Attrition
# 0    55033
# 1    44967
# Name: count, dtype: int64

# %%
data['Attrition'].dtype
# Out:
# dtype('int64')

# %%
# Define a function to detect and remove outliers using the IQR method
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    cleaned_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return cleaned_df

data_cleaned = data.copy()

#  the function to each numeric column to handle outliers
numeric_columns = data_cleaned.select_dtypes(include=['float64', 'int64']).columns  # Assuming 'data_cleaned' is already cleaned for non-numeric issues
for col in numeric_columns:
    data_cleaned = remove_outliers_iqr(data_cleaned, col)

print(f"Data shape after outlier removal: {data_cleaned.shape}")
# Out:
# Data shape after outlier removal: (100000, 13)

# %%
print(f"Final shape of the data: {data_cleaned.shape}")
# Out:
# Final shape of the data: (100000, 13)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize 'data_cleaned' from the previous cleaning step
data_cleaned = data.copy()  # Ensure you're working with the cleaned dataset

# Identify numerical columns but exclude the 'Attrition' column
numeric_columns = data_cleaned.select_dtypes(include=['float64', 'int64']).columns
numeric_columns = numeric_columns.drop('Attrition')  # Exclude the Attrition column

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to the numeric columns and transform the data (excluding 'Attrition')
data_cleaned[numeric_columns] = scaler.fit_transform(data_cleaned[numeric_columns])

# Verify that 'Attrition' is not affected
print(f"Mean of each numeric column after standardization (excluding 'Attrition'):\n{data_cleaned[numeric_columns].mean()}")
print(f"Standard deviation of each numeric column after standardization (excluding 'Attrition'):\n{data_cleaned[numeric_columns].std()}")
# Out:
# Mean of each numeric column after standardization (excluding 'Attrition'):
# EmployeeID          -1.591616e-16
# Age                  1.464606e-17
# MonthlyIncome       -2.982858e-16
# YearsAtCompany       1.287503e-16
# JobSatisfaction     -1.082157e-16
# DistanceFromHome     6.011192e-17
# PerformanceRating    1.399769e-16
# dtype: float64
# Standard deviation of each numeric column after standardization (excluding 'Attrition'):
# EmployeeID           1.000005
# Age                  1.000005
# MonthlyIncome        1.000005
# YearsAtCompany       1.000005
# JobSatisfaction      1.000005
# DistanceFromHome     1.000005
# PerformanceRating    1.000005
# dtype: float64

# %%
data.describe()
# Out:
#           EmployeeID            Age  MonthlyIncome  YearsAtCompany  \
# count  100000.000000  100000.000000  100000.000000   100000.000000
# mean    50035.308080      38.579020   11494.700051       19.566760
# std     27398.069243      11.514398    4662.843192       10.967594
# min         1.000000      18.000000    3000.024559        0.000000
# 25%     27805.750000      29.000000    7700.277100       11.000000
# 50%     50042.500000      39.000000   11484.035057       20.000000
# 75%     72262.250000      48.000000   15281.875092       28.000000
# max    100000.000000      59.000000   19999.985965       39.000000
#
#        JobSatisfaction  DistanceFromHome  PerformanceRating      Attrition
# count      100000.0000     100000.000000      100000.000000  100000.000000
# mean            2.5497         15.043320           2.547770       0.449670
# std             1.0690          7.940583           1.070285       0.497463
# ...

# %%
data.head()
# Out:
#    EmployeeID   Age  Gender EducationLevel                JobRole  \
# 0         1.0  37.0  Female       Bachelor                Manager
# 1         2.0  48.0  Female       Bachelor  Laboratory Technician
# 2         3.0  22.0  Female         Master        Sales Executive
# 3         4.0  27.0    Male       Bachelor                Manager
# 4         5.0  48.0    Male       Bachelor                Manager
#
#    MonthlyIncome  YearsAtCompany WorkLifeBalance  JobSatisfaction OverTime  \
# 0    6524.325054            30.0             Bad              4.0       No
# 1    4665.239398             5.0          Better              4.0      Yes
# 2   17600.801537            37.0            Good              3.0      Yes
# 3   16778.033975            24.0            Best              1.0      Yes
# 4   15510.799372             1.0            Good              3.0       No
#
#    DistanceFromHome  PerformanceRating  Attrition
# 0              29.0                2.0          0
# ...

# %%
# Assuming 'data_cleaned' is your DataFrame containing the cleaned and standardized data
correlation_matrix = data[numeric_columns].corr()
print(correlation_matrix)
# Out:
#                    EmployeeID       Age  MonthlyIncome  YearsAtCompany  \
# EmployeeID           1.000000  0.001423      -0.000045        0.002200
# Age                  0.001423  1.000000      -0.002227       -0.009401
# MonthlyIncome       -0.000045 -0.002227       1.000000       -0.004726
# YearsAtCompany       0.002200 -0.009401      -0.004726        1.000000
# JobSatisfaction      0.000350  0.003566       0.000190        0.005133
# DistanceFromHome     0.000285 -0.006255      -0.000497       -0.004730
# PerformanceRating    0.000843 -0.007506      -0.003807       -0.004410
#
#                    JobSatisfaction  DistanceFromHome  PerformanceRating
# EmployeeID                0.000350          0.000285           0.000843
# Age                       0.003566         -0.006255          -0.007506
# MonthlyIncome             0.000190         -0.000497          -0.003807
# YearsAtCompany            0.005133         -0.004730          -0.004410
# ...

# %%
 # Data visulisation
 figt = ['Age','MonthlyIncome','YearsAtCompany','DistanceFromHome','PerformanceRating','Attrition']
 print(figt)
# Out:
# ['Age', 'MonthlyIncome', 'YearsAtCompany', 'DistanceFromHome', 'PerformanceRating', 'Attrition']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot barplot for categorical variables
categorical_columns = ['Attrition', 'JobRole', 'OverTime']  # Add other relevant columns

for col in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=col, data=data, hue='Attrition')
    plt.xticks(rotation=45)
    plt.title(f'Distribution of {col} by Attrition')
    plt.show()

# %%
data.columns
# Out:
# Index(['EmployeeID', 'Age', 'Gender', 'EducationLevel', 'JobRole',
#        'MonthlyIncome', 'YearsAtCompany', 'WorkLifeBalance', 'JobSatisfaction',
#        'OverTime', 'DistanceFromHome', 'PerformanceRating', 'Attrition'],
#       dtype='object')

# %%
# Plot histogram for numerical columns
for col in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=data, x=col, hue='Attrition', multiple='stack', kde=True)
    plt.title(f'{col} Distribution by Attrition')
    plt.show()

# %%
#encode binary variables
data['OverTime']=data['OverTime'].map({'Yes':1,'No':0})
data['Gender']=data['Gender'].map({'Male':0,'Female':1})
data['OverTime'].value_counts()
data['Gender'].value_counts()
# Out:
# Gender
# 0    55098
# 1    44902
# Name: count, dtype: int64

# %%
data['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive          28101
# Research Scientist       18141
# Laboratory Technician    17952
# Manager                  17932
# Human Resources          17874
# Name: count, dtype: int64

# %%
#encode the categorical columns which ar ordinal , use labelEncoding
#apply label encoder to df_categorical
from sklearn.preprocessing import LabelEncoder
encoding_cols=['JobRole','EducationLevel','WorkLifeBalance']
label_encoders ={}
for col in encoding_cols:
    label_encoders[col]=LabelEncoder()
    data[col]=label_encoders[col].fit_transform(data[col])

# %%
data.head()
# Out:
#    EmployeeID   Age  Gender  EducationLevel  JobRole  MonthlyIncome  \
# 0         1.0  37.0       1               0        2    6524.325054
# 1         2.0  48.0       1               0        1    4665.239398
# 2         3.0  22.0       1               2        4   17600.801537
# 3         4.0  27.0       0               0        2   16778.033975
# 4         5.0  48.0       0               0        2   15510.799372
#
#    YearsAtCompany  WorkLifeBalance  JobSatisfaction  OverTime  \
# 0            30.0                0              4.0         0
# 1             5.0                2              4.0         1
# 2            37.0                3              3.0         1
# 3            24.0                1              1.0         1
# 4             1.0                3              3.0         0
#
#    DistanceFromHome  PerformanceRating  Attrition
# 0              29.0                2.0          0
# 1              20.0                1.0          1
# ...

# %%
# Machine learning : Splitting the data into Traning and Testing Sample
X = data.drop('Attrition',axis=1)
Y = data['Attrition'].values

# %%
#RESAMPLING
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
print(Counter(Y))
rus = RandomOverSampler(random_state=42)
X_over,Y_over = rus.fit_resample(X,Y)
print(Counter(Y_over))
# Out:
# Counter({0: 55033, 1: 44967})
# Counter({0: 55033, 1: 55033})

# %%
#split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X_over,Y_over, test_size = 0.2, random_state= 42)

# %%
print (X_train.shape)
print (X_test.shape)
print (Y_test.shape)
print (Y_train.shape)
# Out:
# (88052, 12)
# (22014, 12)
# (22014,)
# (88052,)

# %%
#Using Logistic Regression in Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
logreg = LogisticRegression()
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
prediction = logreg.predict(X_test)
cnf_matrix=confusion_matrix(Y_test,prediction)
print("Accuracy Score -", accuracy_score(Y_test,prediction))
# Out:
# Accuracy Score - 0.5034523485054965

# %%
fig = plt.figure(figsize=(15,6))
ax1=fig.add_subplot(1,2,1)
ax1=sns.heatmap(pd.DataFrame(cnf_matrix),annot = True,cmap='Blues',fmt='d')
bottom,top=ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)
plt.xlabel('Predicted')
plt.ylabel('Expected')

ax2=fig.add_subplot(1,2,2)
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr,tpr,_ =roc_curve(Y_test,y_pred_proba)
auc=roc_auc_score(Y_test,prediction)
ax2=plt.plot(fpr,tpr,label='data 1 ,auc='+str(auc))
plt.legend(loc=4)
plt.show()
